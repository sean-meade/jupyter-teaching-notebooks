# %% [markdown]
# # Keras neurons

# %%
import keras as kr
import numpy as np
import seaborn as sns
import pandas as pd

# %%
m = kr.models.Sequential()

m.add(kr.layers.Dense(2, input_dim=1, activation="sigmoid", kernel_initializer='ones', bias_initializer='zeros'))
m.add(kr.layers.Dense(1))

m.compile(loss="mean_squared_error", optimizer="sgd")

# %%
df = pd.DataFrame(data=np.linspace(-10.0, 10.0, 1000), columns=["x"])

# %%
df['y'] = m.predict(df['x'])

# %%
df
# Out:
#              x         y
# 0   -10.000000  0.000045
# 1    -9.979980  0.000046
# 2    -9.959960  0.000047
# 3    -9.939940  0.000048
# 4    -9.919920  0.000049
# 5    -9.899900  0.000050
# 6    -9.879880  0.000051
# 7    -9.859860  0.000052
# 8    -9.839840  0.000053
# 9    -9.819820  0.000054
# 10   -9.799800  0.000055
# 11   -9.779780  0.000057
# 12   -9.759760  0.000058
# 13   -9.739740  0.000059
# 14   -9.719720  0.000060
# 15   -9.699700  0.000061
# 16   -9.679680  0.000063
# 17   -9.659660  0.000064
# 18   -9.639640  0.000065
# 19   -9.619620  0.000066
# 20   -9.599600  0.000068
# 21   -9.579580  0.000069
# 22   -9.559560  0.000071
# 23   -9.539540  0.000072
# 24   -9.519520  0.000073
# 25   -9.499499  0.000075
# 26   -9.479479  0.000076
# 27   -9.459459  0.000078
# 28   -9.439439  0.000080
# 29   -9.419419  0.000081
# ..         ...       ...
# 970   9.419419  0.999919
# 971   9.439439  0.999920
# 972   9.459459  0.999922
# 973   9.479479  0.999924
# 974   9.499499  0.999925
# ...

# %%
sns.scatterplot(data=df, x='x', y='y')

# %% [markdown]
# ## End
